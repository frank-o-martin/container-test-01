# %% [markdown]
# # Summary
#
# Below Code was generated by Copilot on asking: I have a list of restaurant names. Often there are variations of specific terms. I would like to create a classification by such terms. How can I find a list with terms that actually exist with variations in the list?

# %%
from sentence_transformers import SentenceTransformer, util
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd
import re

# %%
# ------------------------------------------------------
# 1. Load embedding model
# ------------------------------------------------------
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
# ------------------------------------------------------
# 2. Your restaurant list
# ------------------------------------------------------
restaurants = [
    "Joe's Pizza",
    "Joes Pizzeria",
    "Pizzeria Bella",
    "Thai Express",
    "Thai Xpress",
    "Sushi Bar Kyoto",
    "Kyoto Sushi House"
]

# %%
df = pd.read_csv("data/df_restaurants_counts.csv")
restaurants = df["name"].tolist()
print(f"Loaded {len(restaurants)} restaurant names from CSV.")
# Out:
# Loaded 76840 restaurant names from CSV.

# %%
# ------------------------------------------------------
# 3. Normalize + tokenize
# ------------------------------------------------------
def tokenize(name):
    name = name.lower()
    name = re.sub(r"[^a-zäöüß0-9 ]", " ", name)
    return [t for t in name.split() if t]

tokens = []
for r in restaurants:
    tokens.extend(tokenize(r))

unique_tokens = list(set(tokens))
print("Unique tokens:", unique_tokens)

# ------------------------------------------------------
# 4. Create embeddings
# ------------------------------------------------------
embeddings = model.encode(unique_tokens)

# ------------------------------------------------------
# 5. Cluster tokens based on similarity
# ------------------------------------------------------
# DBSCAN groups points based on distance; eps controls similarity threshold
clustering = DBSCAN(eps=0.35, min_samples=2, metric="cosine").fit(embeddings)

clusters = {}
for token, label in zip(unique_tokens, clustering.labels_):
    clusters.setdefault(label, []).append(token)

# ------------------------------------------------------
# 6. Print clusters
# ------------------------------------------------------
print("\nToken clusters:")
for label, group in clusters.items():
    if label == -1:
        print("Unclustered:", group)
    else:
        print(f"Cluster {label}:", group)
# Out:
# Unique tokens: ['schloßkeller', 'pumpstation', 'eninger', 'eisenhut', 'zollbrücke', 'mie', 'schüler', '18zwo', 'muhl', 'morgenroth', 'roeßing', 'emmas', 'schnoits', 'dönercenter', 'ilion', '89anju', 'siller', 'backes', 'stuttgarter', 'feines19', 'bufalo', 'edenbergen', 'laganini', 'dosa', 'orlenberg', 'jasmy', 'metall', 'bua', 'kühlungsborner', 'muldaer', 'meerbusch', 'adaro', 'shahrzad', 'barolo', 'hohenwarsleben', 'samira', 'wittmund', 'radha', 'lebenshilfe', 'gärtner', 'buhbe', 'fleischeslust', 'dragone', 'uhles', 'pölkenhof', 'alarico', 'saarbrigger', 'stuhlmacher', 'monchis', 'wohnwelt', 'liebesbier', 'hexenhäuschen', 'nr1', 'westensee', 'duo', 'maulwurf', 'vareler', 'speist', 'caverna', 'cava', 'oelkers', 'lönskrug', 'füssen', 'posta', 'moccachino', 'hoffis', 'altöttinger', 'ugo', 'people', '400', 'recke', 'artur', 'klostergarten', 'jit', 'ikea', 'welschof', 'daeli', 'omero', 'düll', 'chhurrinos', 'chocolate', 'plan', 'haueis', 'peperone', 'degustibus', 'inselmühle', 'blick', 'gondelstation', 'leintäle', 'tia', 'chillers', 'sülz', 'christel', 'gianoli', 'woerners', 'wangji', 'raden', 'dek', 'gössini', 'ecker', 'trödelschänke', 'italien', 'leopold', 'tonkatsu', 'hansmann', 'altena', 'issum', 'xxxlutz', 'tapeo', 'brettberg', 'spa', 'diedrich', 'bistro48', 'uli', 'gutacher', 'straßenbahnbetriebshof', 'dudweiler', 'schaft', 'fuchshof', 'chowrasta', 'muck', 'ilvi', 'nordmetal', 'schoppenstübla', 'friesdorfer', 'küchenwerkstatt', 'längsseits', 'schwarze', 'iggelheim', 'bäreneckle', 'radizierte', 'saarbrücker', '07', 'windbeutel', 'kaiserburg', 'traditionsgasthof', 'ingram', 'speisenwirtschaft', 'rosino', 'franko', 'ostende', 'eo', 'feinspitz', 'kleiststube', 'donnerwetter', 'jüterbog', 'vergißmeninicht', 'nafetha', 'weinkontor', 'metelen', 'pivittskrug', 'endressche', 'sonnenbesen', 'rothe', 'mussumer', 'stockie', 'triana', 'menninger', 'matheo', 'mediterranea', 'ever', 'mone', 'alberts', 'röker', 'nile', 'nueva', 'kneiple', 'hundehäusl', 'zippl', 'zwölfender', 'zeisigwaldlehne', 'asslarer', 'schlosscaf', 'breidenstein', 'kirchheimer', 'braunsteinhaus', 'topi', 'gemeinsam', 'pizzaman', 'sigle', 'nordrach', 'kreisi', 'feldhas', 'fellhorn', 'am', 'asiadong', 'rothen', 'flasche', 'hanyu', 'rutenbieger', 'beekays', 'hechtkopf', 'kaminstübchen', 'elvis', 'pagano', 'lohni', 'waldseiter', 'gymnasium', 'donoperteich', 'kortlüke', 'hoseki', 'klosterburgstuben', 'wittekind', 'bergschloß', 'bundesbüdchen', 'waid', 'brunnenthal', 'darßer', 'oude', 'einruhr', 'streng', 'fegetasch', 'jerry', 'tito', 'körter', 'autobahn', 'kulturküche', 'innblick', 'korali', 'cremering', 'westerbachhalle', 'waldeckhof', 'stammklause', 'paladar', 'blümel', 'ionio', 'bayerisch', 'jörg', 'rattenkrug', 'ajad', 'viatoni', 'dümmerkrug', 'fischmeisterei', 'radmosphäre', 'guo', 'thurm', 'bruhns', 'hähnchen', 'helenas', 'sinneswandel', 'reinheim', 'brunnwies', 'lohmüller', 'kolonie', 'spässchen', 'kurier', 'svm', 'nakorn', 'isenburg', 'askitis', 'sofra', 'vitale', 'kreuziger', 'bellas', 'schmiede1860', 'deno', 'lüches', 'svo', 'sawadee', 'bacherer', 'hopfestubb', 'bue', 'neckar', 'nett', 'hinhart', 'buya', 'feldberghaus', 'lamaz', 'makenhofstüble', 'kantine', 'yen', 'kikis', 'lidova', 'cago', 'blüte', 'adra', 'förthen', 'aromatisch', 'gesellschaftsräume', 'abendruh', 'asbeck', 'tastypottgbr', 'disam', 'nordheim', 'papen', 'sevdah', 'bambusstäbchen', 'schwanefeld', 'mettnau', 'schwarzwaldverein', 'walserberg', 'sallo', 'flux', 'horbach', 'schürholz', 'freitaler', 'fürsteneck', 'schoene', 'strandgaststätte', 'skv', 'peif', 'kieferer', 'walts', 'drosten', 'phai', 'asiaimbiss', 'hagkopf', 'allerhof', 'malvasia', 'steppach', 'sui', 'kleemann', 'schoko', 'forellenstube', 'genusswerk', 'treffer', 'addel', 'bivels', 'ketzberg', 'bandito', 'mehdi', 'heigl', 'brigitte', 'frangel', 'bist', 'burglengenfeld', 'palmbräu', 'hainan', 'löffelbar', 'jackies', 'hasenbürener', 'sonneborn', 'pablo', 'zehntkeller', 'lichtenstein', 'keeken', 'gohlis', 'fertig', 'fortunella', 'half', 'zusam ...
#
# Token clusters:
# Cluster 0: ['schloßkeller', 'pumpstation', 'eninger', 'eisenhut', 'zollbrücke', 'mie', 'schüler', '18zwo', 'muhl', 'morgenroth', 'roeßing', 'emmas', 'schnoits', 'dönercenter', 'ilion', '89anju', 'siller', 'backes', 'stuttgarter', 'feines19', 'bufalo', 'edenbergen', 'laganini', 'dosa', 'orlenberg', 'jasmy', 'bua', 'kühlungsborner', 'muldaer', 'meerbusch', 'adaro', 'shahrzad', 'barolo', 'hohenwarsleben', 'samira', 'wittmund', 'lebenshilfe', 'gärtner', 'buhbe', 'fleischeslust', 'dragone', 'uhles', 'pölkenhof', 'alarico', 'saarbrigger', 'stuhlmacher', 'monchis', 'wohnwelt', 'liebesbier', 'hexenhäuschen', 'nr1', 'westensee', 'maulwurf', 'vareler', 'speist', 'caverna', 'cava', 'oelkers', 'lönskrug', 'posta', 'moccachino', 'hoffis', 'altöttinger', 'ugo', '400', 'recke', 'artur', 'klostergarten', 'jit', 'welschof', 'daeli', 'omero', 'düll', 'chocolate', 'haueis', 'peperone', 'degustibus', 'inselmühle', 'blick', 'gondelstation', 'leintäle', 'tia', 'chillers', 'sülz', 'christel', 'gianoli', 'woerners', 'wangji', 'raden', 'dek', 'gössini', 'ecker', 'trödelschänke', 'italien', 'tonkatsu', 'hansmann', 'altena', 'issum', 'xxxlutz', 'tapeo', 'brettberg', 'spa', 'bistro48', 'uli', 'gutacher', 'straßenbahnbetriebshof', 'dudweiler', 'schaft', 'fuchshof', 'muck', 'ilvi', 'nordmetal', 'schoppenstübla', 'friesdorfer', 'küchenwerkstatt', 'längsseits', 'schwarze', 'iggelheim', 'bäreneckle', 'radizierte', 'saarbrücker', '07', 'windbeutel', 'kaiserburg', 'traditionsgasthof', 'speisenwirtschaft', 'rosino', 'franko', 'ostende', 'eo', 'feinspitz', 'kleiststube', 'donnerwetter', 'jüterbog', 'vergißmeninicht', 'nafetha', 'weinkontor', 'metelen', 'pivittskrug', 'endressche', 'sonnenbesen', 'rothe', 'mussumer', 'stockie', 'triana', 'menninger', 'matheo', 'mediterranea', 'mone', 'alberts', 'röker', 'nueva', 'kneiple', 'hundehäusl', 'zippl', 'zwölfender', 'zeisigwaldlehne', 'asslarer', 'schlosscaf', 'breidenstein', 'kirchheimer', 'braunsteinhaus', 'topi', 'gemeinsam', 'pizzaman', 'sigle', 'nordrach', 'kreisi', 'feldhas', 'fellhorn', 'asiadong', 'rothen', 'flasche', 'hanyu', 'rutenbieger', 'beekays', 'hechtkopf', 'kaminstübchen', 'pagano', 'lohni', 'waldseiter', 'donoperteich', 'kortlüke', 'hoseki', 'klosterburgstuben', 'wittekind', 'bergschloß', 'bundesbüdchen', 'waid', 'brunnenthal', 'darßer', 'oude', 'einruhr', 'streng', 'fegetasch', 'körter', 'autobahn', 'kulturküche', 'innblick', 'korali', 'cremering', 'westerbachhalle', 'waldeckhof', 'stammklause', 'paladar', 'blümel', 'ionio', 'bayerisch', 'jörg', 'rattenkrug', 'ajad', 'dümmerkrug', 'fischmeisterei', 'radmosphäre', 'guo', 'thurm', 'bruhns', 'hähnchen', 'sinneswandel', 'reinheim', 'brunnwies', 'lohmüller', 'kolonie', 'spässchen', 'kurier', 'svm', 'nakorn', 'isenburg', 'sofra', 'vitale', 'kreuziger', 'bellas', 'schmiede1860', 'deno', 'lüches', 'svo', 'sawadee', 'bacherer', 'hopfestubb', 'bue', 'neckar', 'nett', 'hinhart', 'buya', 'feldberghaus', 'kantine', 'yen', 'kikis', 'lidova', 'cago', 'blüte', 'adra', 'aromatisch', 'gesellschaftsräume', 'abendruh', 'asbeck', 'disam', 'nordheim', 'papen', 'sevdah', 'bambusstäbchen', 'schwanefeld', 'mettnau', 'schwarzwaldverein', 'walserberg', 'sallo', 'horbach', 'schürholz', 'freitaler', 'fürsteneck', 'schoene', 'strandgaststätte', 'skv', 'peif', 'kieferer', 'walts', 'drosten', 'phai', 'asiaimbiss', 'hagkopf', 'allerhof', 'malvasia', 'steppach', 'kleemann', 'schoko', 'forellenstube', 'genusswerk', 'treffer', 'addel', 'ketzberg', 'mehdi', 'heigl', 'brigitte', 'frangel', 'bist', 'burglengenfeld', 'palmbräu', 'hainan', 'löffelbar', 'hasenbürener', 'sonneborn', 'zehntkeller', 'lichtenstein', 'keeken', 'gohlis', 'zusamzell', 'neuenahr', 'historischen', 'weserbogen', 'canaletto', 'breilklause', 'hilgensteen', 'mariensee', 'restauranz', 'dachsbräu', 'klemenz', 'iuma', 'erbeldinger', 'sendesaal', 'lua', 'waldauerle', 'klippenberg', 'milazzo', 'mazi', 'sebastianus', 'camilio', 'stöckle', 'limani', 'bauernhannla', 'oberndorfer', 'efg', 'arabella', 'ampelos', 'fritsching', 'strau ...
# Unclustered: ['metall', 'people', 'ikea', 'chhurrinos', 'diedrich', 'ingram', 'ever', 'nile', 'am', 'gymnasium', 'tito', 'viatoni', 'askitis', 'makenhofstüble', 'förthen', 'tastypottgbr', 'flux', 'bivels', 'pablo', 'sernjanski', 'zebib', 'becasse', 'bedarfshaltestelle', 'rockstation', 'partyraum', 'malteserstraße', 'clair', 'edgar', 'wemag', 'finesse', 'funky', 'duffel', 'paso', 'lucky', 'tendoori', 'foodbreak20', 'foyer', 'line', '4fellows', 'alexandria', 'penalty', 'vicari', 'outbax', 'wombae', 'slot', 'swamy', 'suez', 'news', 'cardinale', 'regierungspräsidium', 'presente', 'done', 'nelson', 'grieff', 'hq', 'füllort', 'truppacher', 'leutnant', 'salem', 'shwarma', 'nora', 'self', 'steverstrand', 'pholosophy', 'allan', 'filderpost', 'epsilon', 'owingen', 'orpheum', 'bleaml', 'help', 'montgomery', 'sandersküper', 'camelo', 'salute', 'steinrade', 'bliss', 'haryana', 'lncontro', 'octopus', 'clyde', 'kristin', 'uddin', 'celeste', 'hasentreff', 'wheat', 'planwagenfahrten', 'epic', 'dibberns', 'liu', 'freddy', 'time2taste', 'oachkatzl', 'all', 'ikarus', 'arens', 'rules', 'astoria', 'duchessa', 'diverso', 'struwwelpeter', 'halfbrodt', '1670', 'mymoon', 'lydia', 'biohotel', 'magellan', 'schaumberg', 'loyal', 'far', 'orpheus', 'triangle', 'optimismus', 'antiche', 'loretta', 'julie', 'synantisis', 'joolee', 'eglantine', 'smashed', 'creole', 'spectacel', 'drama', 'cosmos', 'rhodes', 'petrol', 'gao', 'beetle', 'terence', 'clip', 'nombre', '2times', 'vanilla', 'vorgebirgsblick', 'abs', 'fasil', 'mitch', 'dhillon', 'water', 'mace', 'hookah', 'dracula', 'aischblick', 'fit', 'smart', 'dioklecian', 'sarajevo', 'https', '911', 'fkv', 'concorde', 'peacock', 'laguna', 'vahrenholt', 'brutal', 'fjord', 'aimy', 'highlander', 'escape', 'glindskoppel', 'firlefanz', 'raoul', 'true', 'real', 'klindworths', 'plumeau', 'moevenpick', 'balance', 'this', 'plastics', 'madeira', 'virtuous', 'chance', 'motek', 'luke', 'memmelsdorf', 'notschreipass', '7fuji', 'sh', 'lynn', 'connection', 'longobardi', 'lagallerie', 'delivery', 'geerdes', 'tango', 'preesters', 'cheers', 'lucha', 'backshop', 'oveney', 'mafia', 'diskothek', 'td', 'eden', 'naupoldsmühle', 'qasr', 'grewal', 'nate', '2go', 'tentacion', 'gerry', 'confidential', 'scenario', 'aquila', 'chickenpickin', 'dolphin', 'mildred', 'clintons', 'vagueira', 'zwentibold', 'blazek', 'panolio', 'colibri', 'pächterwechsel', 'aventoft', 'sellweiden', 'rogers', 'laspediras', 'mulberry', 'amthaisong', 'thouli', 'marinekameradschaft', 'herkules', 'minnieci', 'folia', 'toulon', 'blackforest', 'moneypenny', 'pottpourri', 'friedmanns', 'prism', 'too', 'spökes', 'vdoma', 'domaine1795', 'date', 'perouse', 'eco', 'then', 'spielberg', '90secondi', 'gopal', 'hr', 'overath', 'having', 'steppe', 'trachenberge', 'cones', 'zeven', 'peltzer', 'oops', 'song', 'fairplay', 'achilles', 'nobless', 'integration', 'spare', 'crackers', 'cottbus', 'pandora', 'abseits', 'signature', 'einehandvoll', 'boulodrome', 'kongsnaes', 'baku', 'mx465', 'diverse', 'visavis', 'comeback', 'ito', 'galerie', 'arun', 'carbonara', 'scootershop', 'comviet', 'volley', 'cetera', 'swat', 'of', 'lawarka', 'najm', 'bürstenbinder', 'cascade', 'heartcore', 'forkenhannes', 'hidding', 'crazy', 'limni', 'peerstall', 'lagger', 'revolution', 'joey', 'störmede', 'avila', 'grange', 'praxis', 'safari', 'derby', 'polizeipräsidium', 'rosenthal', 'tripoli', 'ghanoudj', 'apicius', 'acacia', 'patron', 'denny', 'coolibri', 'world', 'netsu', 'vierzehn85', 'posteria', 'kazan', 'timeless', 'etihad', 'kepler', 'letterman', 'dostoevsky', 'corona', 'theta', 'portrait', 'homeservice', 'compass', 'quovadis', 'diamond', 'badewanne', 'lijianger', 'toyama', 'future', 'georgie', 'radental', 'cospuden', 'craft', 'mövenpick', 'hmtmh', 'brandy', 'architect', 'inspire', '4cani', 'nohut', 'guliettas', 'gallipoli', 'inclusive', 'citychicken', 'iyads', 'kind', 'fusion', 'quarks', 'concerto', 'ahmad', 'granny', 'piraeus', 'postkarle', 'amphora', 'part', 'mbassy', 'hilda', 'isswasgutes', 'for', 'mesa', 'yu ...
# Cluster 1: ['radha', 'radhaus']
# Cluster 2: ['duo', 'duomo']
# Cluster 3: ['füssen', 'füssing', 'füssner']
# Cluster 4: ['plan', 'plancha']
# Cluster 5: ['leopold', 'leopoldsplatz', 'leopoldshöhe']
# Cluster 6: ['chowrasta', 'chow', 'chowk', 'chows']
# Cluster 7: ['elvis', 'elvish']
# Cluster 8: ['jerry', 'larry']
# Cluster 9: ['helenas', 'helena']
# Cluster 10: ['lamaz', 'palios', 'lamäng', 'lama', 'palinuro', 'palio', 'palito', 'pali', 'lamato']
# Cluster 11: ['sui', 'sue', 'suey', 'suer', 'suerlaenner', 'suisse', 'suigyo']
# Cluster 12: ['bandito', 'bandits', 'banditas']
# Cluster 13: ['jackies', 'jackie']
# Cluster 14: ['fertig', 'fertigungsbereich']
# Cluster 15: ['fortunella', 'fortune']
# Cluster 16: ['half', 'halfway']
# Cluster 17: ['bäckstage', 'backstage']
# Cluster 18: ['lone', 'lonetal', 'solo', 'lonestar']
# Cluster 19: ['urfttalsperre', 'triftsperre']
# Cluster 20: ['anders', 'anderswie', 'andersch']
# Cluster 21: ['statt', 'statale', 'stather']
# Cluster 22: ['lizbät', 'liz', 'lizzy']
# Cluster 23: ['evelyn', 'edith']
# Cluster 24: ['filmriss', 'movies', 'filmdose', 'filmkiste', 'filmforum', 'film', 'filmbühne']
# Cluster 25: ['sabine', 'sabines']
# Cluster 26: ['jacky', 'jackys', 'jack', 'jackels', 'jackob']
# Cluster 27: ['spurk', 'spuren']
# Cluster 28: ['because', 'why']
# Cluster 29: ['orexi', 'orex', 'orestis']
# Cluster 30: ['choi', 'chois']
# Cluster 31: ['everding', 'evers']
# Cluster 32: ['lila', 'lilavadee']
# Cluster 33: ['hoven', 'hövel', 'höver']
# Cluster 34: ['leos', 'leo', 'leopolt', 'leoli', 'leoes', 'leogrande']
# Cluster 35: ['denis', 'denissimo']
# Cluster 36: ['maono', 'maots', 'mao']
# Cluster 37: ['filetshop', 'filetgran', 'filetstück']
# Cluster 38: ['patricias', 'patricia']
# Cluster 39: ['container', 'dock', 'underdocks', 'dock8', 'dockemeyer', 'dockline', 'paddock', 'dock10']
# Cluster 40: ['waldorfer', 'waldoza', 'waldoase']
# Cluster 41: ['annoir', 'comptoir']
# Cluster 42: ['baltico', 'rigatoni', 'vilnius', 'baltic', 'gdanska', 'rigani', 'riganato']
# Cluster 43: ['longh', 'longen', 'long']
# Cluster 44: ['anitas', 'anita']
# Cluster 45: ['eddy', 'eddys']
# Cluster 46: ['bains', 'bainian']
# Cluster 47: ['garcia', 'miguel', 'alfonsos', 'rivera', 'emilio', 'alfonso', 'armando', 'miguelitos']
# Cluster 48: ['plata', 'platano', 'platamon']
# Cluster 49: ['piratenschänke', 'piraten', 'piratennest', 'pirates']
# Cluster 50: ['tramontana', 'tramonti', 'tramonto', 'tramezzini', 'traminer', 'tram']
# Cluster 51: ['emmering', 'permeringer', 'emmeringer']
# Cluster 52: ['vong', 'von']
# Cluster 53: ['xaver', 'xaverlwirt', 'xavers']
# Cluster 54: ['maruyasu', 'maruzzella', 'maruba', 'marubi', 'maru']
# Cluster 55: ['blinkfüür', 'blinkfuer', 'blinkfür', 'blink']
# Cluster 56: ['heidi', 'heidinger', 'kathys', 'heidis']
# Cluster 57: ['roles', 'rolef']
# Cluster 58: ['cedars', 'cedar']
# Cluster 59: ['laude', 'laudensack', 'laudenauer']
# Cluster 60: ['dream', 'dreams']
# Cluster 61: ['boomhus', 'boom', 'boomi']
# Cluster 62: ['galactica', 'milky', 'galaxy']
# Cluster 63: ['carla', 'carmens', 'carmen', 'carlas']
# Cluster 64: ['lava', 'basalt', 'lavas', 'volcano', 'basaltmine']
# Cluster 65: ['liebner', 'ebner', 'griebner']
# Cluster 66: ['loistl', 'loisi', 'loisl', 'loisachstuben', 'loissin']
# Cluster 67: ['lovers', 'loving', 'romantica', 'loverr', 'amour', 'love', 'lover', 'partner', 'romantico', 'amore', 'romance']
# Cluster 68: ['slow', 'speed', 'quick', 'faster', 'speedy', 'fast', 'speedys']
# Cluster 69: ['nobelhart', 'nobel']
# Cluster 70: ['loungerie', 'loungecafe', 'lounge']
# Cluster 71: ['harm', 'harms']
# Cluster 72: ['vibes', 'vibez', 'vibe']
# Cluster 73: ['mondfahrt', 'radfahrstation']
# Cluster 74: ['tbvfl', 'tbg']
# Cluster 75: ['basics', 'basic']
# Cluster 76: ['fame', 'famous']
# Cluster 77: ['harry', 'harrys']
# Cluster 78: ['cousina', 'cousine', 'auntie', 'aunty', 'uncle']
# Cluster 79: ['boxer', 'boxerclub']
# Cluster 80: ['nw', 'nwirt']
# Cluster 81: ['casper', 'caspers']
# Cluster 82: ['sormitzblick', 'sormitztal', 'soerstal']
# Cluster 83: ['lim', 'lims', 'limnos', 'limmehr']
# Cluster 84: ['harveys', 'harvey']
# Cluster 85: ['william', 'williamine']
# Cluster 86: ['lambertushof', 'lambertus', 'lambertskreuz']
# Cluster 87: ['ripasso', 'ripieno']
# Cluster 88: ['kanepee', 'kaneo', 'kane']
# Cluster 89: ['hideaway', 'hidden', 'takeaway', 'hiddenseer', 'hiddensee', 'hiddenserborn']
# Cluster 90: ['raffiness', 'raffneralm', 'raffelwirt', 'raffael', 'raffa', 'rafih', 'raffaeles', 'raffaello', 'raffinesse', 'raffaella', 'raffaela', 'raffaele', 'rafa']
# Cluster 91: ['annabelle', 'daisy']
# Cluster 92: ['gaul', 'gaulwirt']
# Cluster 93: ['tommys', 'tommy']
# Cluster 94: ['alfa', 'alfama']
# Cluster 95: ['manuela', 'manuelas', 'manuel']
# Cluster 96: ['has', 'haven']
# Cluster 97: ['daxlanden', 'dax']
# Cluster 98: ['antipasti', 'antipasto']
# Cluster 99: ['ai', 'ais']
# Cluster 100: ['sheikh', 'emir', 'emira', 'emirgan', 'emirates', 'dubai']
# Cluster 101: ['seekieker', 'seekrug', 'seekiosk', 'seekate', 'seekuh', 'seekirch', 'seekiste', 'seekneipe', 'seeklause', 'seeküche']
# Cluster 102: ['possecker', 'poseidon', 'posseidon', 'possen']
# Cluster 103: ['novo2', 'novo']
# Cluster 104: ['stress', 'stressfrei']
# Cluster 105: ['schubert', 'schubertweg', 'schuberth']
# Cluster 106: ['flora', 'florans', 'botanico', 'floratreff', 'botanica', 'floras']
# Cluster 107: ['zeitung', 'zeitungsente']
# Cluster 108: ['üstadin', 'ustan']
# Cluster 109: ['divan', 'diva']
# Cluster 110: ['stövers', 'kettler', 'stover']
# Cluster 111: ['basel', 'baseler', 'baselblick']
# Cluster 112: ['hangar', 'hangard']
# Cluster 113: ['viva', 'vivarepas', 'vivaldi', 'vivantes']
# Cluster 114: ['spirit', 'soul25', 'soulfood', 'soultapas', 'soul', 'soulmate', 'soulas', 'soulm8']
# Cluster 115: ['gus', 'gusi', 'gushu', 'gusan']
# Cluster 116: ['feelgood', 'feel']
# Cluster 117: ['jay', 'jayme', 'jaylano', 'jayden']
# Cluster 118: ['socken', 'sockenschuss']
# Cluster 119: ['atawich', 'hartwich', 'mcdarwich', 'ewich']
# Cluster 120: ['köppen', 'koppen', 'koppenretscher']
# Cluster 121: ['potsdamer', 'potsdam']
# Cluster 122: ['loaner', 'lenderstuben', 'lender', 'lenders']
# Cluster 123: ['clouds', 'cloud']
# Cluster 124: ['standl', 'standort', 'standy', 'standesamt', 'standesämtchen', 'standortcasino']
# Cluster 125: ['memos', 'memorie', 'memoria', 'memogrill', 'memo']
# Cluster 126: ['blanc', 'blanche']
# Cluster 127: ['ritas', 'rita']
# Cluster 128: ['exquisit', 'equit']
# Cluster 129: ['monster', 'beast']
# Cluster 130: ['gretchen', 'gretchens']
# Cluster 131: ['devino', 'devin']
# Cluster 132: ['gapshap', 'gap']
# Cluster 133: ['singer', 'sing', 'sang']
# Cluster 134: ['albrechts', 'albrecht', 'albrechtshain', 'albrechtshöhe', 'albrechtshof']
# Cluster 135: ['plänkschder', 'plank', 'plänkschter']
# Cluster 136: ['open', 'closed']
# Cluster 137: ['amrut', 'unstrut', 'unterstall', 'unstruttal']
# Cluster 138: ['players', 'player']
# Cluster 139: ['defne', 'deftige', 'deftig']
# Cluster 140: ['centrinum', 'centumcellae', 'centrum', 'cent', 'centar', 'centovini', 'centgraf', 'cento']
# Cluster 141: ['visione', 'eye', 'vision']
# Cluster 142: ['emil', 'emils']
# Cluster 143: ['coppola', 'coppia']
# Cluster 144: ['yummy', 'tasty', 'delicious']
# Cluster 145: ['jenzig', 'jennerwein', 'jennerkaser', 'jento', 'jenneralm', 'jenka', 'angelina', 'jen']
# Cluster 146: ['mix', 'mixx', 'mixed', 'blend', 'mixto', 'mixtaurant']
# Cluster 147: ['buddhas', 'buddha']
# Cluster 148: ['elkofen', 'elkes', 'elke']
# Cluster 149: ['augustenstüble', 'augustenthal', 'augustestube']
# Cluster 150: ['foxy', 'fox']
# Cluster 151: ['palmeras', 'palmera']
# Cluster 152: ['lucano', 'lucania', 'lucana']
# Cluster 153: ['sicking', 'sicken']
# Cluster 154: ['binnerlindl', 'binnerschreiner']
# Cluster 155: ['rebels', 'rebeli', 'rebelot', 'rebel', 'rebell']
# Cluster 156: ['poolblick', 'waterblick', 'pool', 'billiardpark']
# Cluster 157: ['mariona', 'marions', 'mariono']
# Cluster 158: ['behringers', 'lothringer', 'möhringer', 'zähringer', 'böhringer', 'behringersmühle', 'mehringer', 'behringer']
# Cluster 159: ['pistors', 'pistor']
# Cluster 160: ['mints', 'mintons', 'mintard', 'mint', 'mintraching']
# Cluster 161: ['anime', 'cartoon']
# Cluster 162: ['ching', 'chingu']
# Cluster 163: ['sailer', 'sailerkeller']
# Cluster 164: ['chips', 'chip']
# Cluster 165: ['grossjung', 'grosswirt', 'grossrotter', 'grossmarkthalle', 'gross', 'grosse', 'grösseltal', 'grossarth', 'grössenwahn', 'grosser']
# Cluster 166: ['cosmo', 'cosmoveda']
# Cluster 167: ['matildas', 'matilda']
# Cluster 168: ['imperiale', 'empire', 'imperial']
# Cluster 169: ['ivonna', 'emmanuel', 'emanuele', 'ivo', 'emanuela', 'emanuel']
# Cluster 170: ['merlino', 'merlind', 'merlinos', 'merlin']
# Cluster 171: ['mahal', 'mahalo', 'mahalakshmi']
# Cluster 172: ['pandaking', 'pandaria', 'panda']
# Cluster 173: ['ishot', 'redhot']
# Cluster 174: ['cookie', 'cookies']
# Cluster 175: ['fatal', 'die', 'death', 'killer', 'killed']
# Cluster 176: ['things', 'thing', 'stuff']
# Cluster 177: ['texter', 'textor']
# Cluster 178: ['hügoloss', 'hugos', 'hugo']
# Cluster 179: ['washoku', 'fokuss', 'yasoroku86']
# Cluster 180: ['fiamme', 'fiaker']
# Cluster 181: ['lankan', 'ceylonas', 'colombo', 'ceylonilicous', 'ceylon']
# Cluster 182: ['ofelia', 'cornelia']
# Cluster 183: ['zoey', 'zoee', 'zoe']
# Cluster 184: ['shan', 'ming', 'mingiu', 'mingers', 'mingo', 'shandiz', 'shaniu', 'shanty', 'shanti', 'shanxi']
# Cluster 185: ['saxophone', 'saxler', 'saxa']
# Cluster 186: ['getränkemarkt', 'getränkeshop', 'getränke', 'getränkescheune']
# Cluster 187: ['institutsviertel', 'institut']
# Cluster 188: ['lessings', 'lessing']
# Cluster 189: ['bakers', 'baker', 'bakery']
# Cluster 190: ['stümpelstal', 'stumpf', 'stumpfar', 'stumpfen', 'stumpfes']
# Cluster 191: ['social', 'socialclub']
# Cluster 192: ['jungle', 'junglen']
# Cluster 193: ['benito', 'benitos']
# Cluster 194: ['corange', 'corazon']
# Cluster 195: ['airport', 'airfield']
# Cluster 196: ['favorit', 'favorita']
# Cluster 197: ['milos', 'novak', 'jugoslavia', 'jugoslavija']
# Cluster 198: ['zanzibar', 'sansibar']
# Cluster 199: ['nero', 'nerotal', 'neromilos']
# Cluster 200: ['joker', 'batman', 'jokers']
# Cluster 201: ['amber', 'amberd', 'amberger', 'amberg']
# Cluster 202: ['theos', 'theo']
# Cluster 203: ['break', 'breakpoint', 'breaktime']
# Cluster 204: ['wieland', 'wielandshöhe', 'wielands']
# Cluster 205: ['dörmann', 'dormont', 'dormero']
# Cluster 206: ['rudolph', 'santa', 'santangela', 'santafe', 'clausing', 'claus', 'rudolphia']
# Cluster 207: ['scaramanga', 'scarpati', 'scaraba', 'scarra', 'scarabeo', 'scarpetta']
# Cluster 208: ['naveena', 'nave']
# Cluster 209: ['leander', 'lean', 'leandro', 'leandros']
# Cluster 210: ['mkhunaa', 'mkv', 'mk']
# Cluster 211: ['keyf', 'keyfi', 'keyfet', 'keyif', 'keyma']
# Cluster 212: ['emigranti', 'emigrant']
# Cluster 213: ['gui', 'uis']
# Cluster 214: ['dionys', 'dionysus', 'dione', 'dionysos', 'dion', 'dionisos', 'dionyssos', 'dionysopolis', 'dioni']
# Cluster 215: ['karina', 'daniela', 'karins', 'karin', 'kristina', 'johannas', 'erika', 'johanna']
# Cluster 216: ['hues', 'hue', 'hueck']
# Cluster 217: ['urtyp', 'urfels', 'urthel']
# Cluster 218: ['lombardi', 'lombardo']
# Cluster 219: ['alpsee', 'canton', 'alpspitze', 'alpine', 'alps', 'alpstuben']
# Cluster 220: ['pascale', 'pascals']
# Cluster 221: ['dakota', 'lakota']
# Cluster 222: ['nassauhafen', 'nassauer', 'nassau']
# Cluster 223: ['özadana', 'apadana']
# Cluster 224: ['platon', 'platonas']
# Cluster 225: ['cada', 'caduli', 'cadoro']
# Cluster 226: ['fantastica', 'fantastico', 'splendido']
# Cluster 227: ['darwins', 'darwineum', 'darwin']
# Cluster 228: ['height', 'heights']
# Cluster 229: ['simatsgund', 'simas']
# Cluster 230: ['carellas', 'carella']
# Cluster 231: ['schumacher', 'schumachers']
# Cluster 232: ['limeskastell', 'limette', 'limes', 'lime']
# Cluster 233: ['ds', 'dsc', 'dschingis']
# Cluster 234: ['qbar', 'marinos', 'qba', 'qb', 'marino']
# Cluster 235: ['based', 'basedau']
# Cluster 236: ['marc', 'marca']
# Cluster 237: ['sparkasse', 'spark']
# Cluster 238: ['finest', 'finestra', 'finestre']
# Cluster 239: ['waldner', 'lindner', 'lodner', 'dresdner', 'bodner']
# Cluster 240: ['copa', 'copas', 'copacabana']
# Cluster 241: ['amaranth', 'amara', 'amaranto']
# Cluster 242: ['decker', 'deckers']
# Cluster 243: ['prison', 'parole']
# Cluster 244: ['colonia', 'colonne']
# Cluster 245: ['bonotti', 'bonomi', 'bono']
# Cluster 246: ['vulcano', 'vulcani', 'vulcanello']
# Cluster 247: ['kentauros', 'kentaro']
# Cluster 248: ['macks', 'mäcki', 'mack']
# Cluster 249: ['fashion', 'style']
# Cluster 250: ['semi', 'semir']
# Cluster 251: ['petra', 'petras', 'petrarca']
# Cluster 252: ['sugarfree', 'sugar']
# Cluster 253: ['jockele', 'jock', 'jöckel', 'jockers']
# Cluster 254: ['surfcenter', 'surf']
# Cluster 255: ['fair', 'fair1']
# Cluster 256: ['starennest', 'starenkasten']
# Cluster 257: ['django', 'imango']
# Cluster 258: ['spilling', 'spiller']
# Cluster 259: ['mythai', 'mythais', 'mythos', 'mythologia']
# Cluster 260: ['danakil', 'danando', 'dana']
# Cluster 261: ['hatoyama', 'hatay', 'hatzl', 'hatz', 'hattrick', 'hatoky', 'hatsukoi', 'hatari', 'hato', 'hat']
# Cluster 262: ['karmann', 'karma', 'karmasee']
# Cluster 263: ['cyn', 'cyclades', 'cyclo']
# Cluster 264: ['theodor', 'theodorus', 'theodors']
# Cluster 265: ['normandie', 'normansteinblick']
# Cluster 266: ['sanders', 'bernie']
# Cluster 267: ['mangos', 'mango', 'mangold', 'mangostin']
# Cluster 268: ['loser', 'löser']
# Cluster 269: ['freshsub', 'fresh']
# Cluster 270: ['fonduehütte', 'fonda', 'fondels']
# Cluster 271: ['pavilion', 'pavilione']
# Cluster 272: ['dell', 'delli', 'delling', 'dello', 'dellys']
# Cluster 273: ['smiley', 'smileys']
# Cluster 274: ['odinius', 'odin', 'odinshain', 'odins']
# Cluster 275: ['charmant', 'charme', 'charm']
# Cluster 276: ['förderverein', 'fordkort', 'förderturm', 'förde']
# Cluster 277: ['tournedo', 'touray']
# Cluster 278: ['mason', 'masons']
# Cluster 279: ['sonnys', 'sonny']
# Cluster 280: ['origine', 'originale', 'original', 'originali']
# Cluster 281: ['aldo', 'aldos']
# Cluster 282: ['martha', 'marthas', 'marthabräu']
# Cluster 283: ['vugelbeerschänk', 'vugelbeerbaam']
# Cluster 284: ['synderhauf', 'synergy', 'syndeo']
# Cluster 285: ['looping', 'loop']
# Cluster 286: ['basilikum', 'basil', 'basilico']
# Cluster 287: ['3hs', '3h']
# Cluster 288: ['grüntal', 'grünthal', 'grüntee', 'grüntenglück', 'grüntenblick']
# Cluster 289: ['ellund', 'edlunds']
# Cluster 290: ['come', 'coming']
# Cluster 291: ['boldekow', 'böld', 'bold']
# Cluster 292: ['bobby', 'bobbys']
# Cluster 293: ['was', 'is']
# Cluster 294: ['oscars', 'emmys', 'oscar']
# Cluster 295: ['lana', 'reginas', 'regina']
# Cluster 296: ['angelos', 'angelo']
# Cluster 297: ['novelle', 'novello']
# Cluster 298: ['lennards', 'lennard']
# Cluster 299: ['360grad', '360']
# Cluster 300: ['gill', 'gille', 'gillot']
# Cluster 301: ['wasabi', 'wasabifun', 'waschsalon']
# Cluster 302: ['clock', 'clockwork']
# Cluster 303: ['field', 'infield']
# Cluster 304: ['civico25', 'civico']
# Cluster 305: ['dümpfelschöpfer', 'dumplinghouse', 'dump', 'dumplings', 'dümptener', 'dumpling']
# Cluster 306: ['hanoi46', 'hanoi']
# Cluster 307: ['anfore', 'anfora']
# Cluster 308: ['jordans', 'jordanbad', 'jordan']
# Cluster 309: ['blondies', 'blond']
# Cluster 310: ['yerevan', 'armenia']
# Cluster 311: ['lola', 'lolas']
# Cluster 312: ['martas', 'marta']
# Cluster 313: ['pale', 'palestra', 'paledo', 'paleo', 'paletti']
# Cluster 314: ['quadriga', 'quadrato', 'quadrium']
# Cluster 315: ['creation', 'creator']
# Cluster 316: ['tagesbar', 'tagbar']
# Cluster 317: ['htc', 'htcn']
# Cluster 318: ['domino', 'dominos']
# Cluster 319: ['peerless', 'peerd', 'peerdkiecker']
# Cluster 320: ['depothek', 'depot']
# Cluster 321: ['riffkieker', 'riff', 'riffer']
# Cluster 322: ['feer', 'manaqish', 'manakish', 'mana', 'templer', 'mager', 'maget', 'manar']
# Cluster 323: ['bustaurant', 'bustan']
# Cluster 324: ['nose', 'face']
# Cluster 325: ['lie', 'truth', 'lies']
# Cluster 326: ['hugis', 'hügle', 'hug', 'huggert', 'hugl']
# Cluster 327: ['dancing', 'dance', 'candance']
# Cluster 328: ['craftlux', 'underlux']
# Cluster 329: ['wraps', 'wrap', 'wrapper', 'wrapublic']
# Cluster 330: ['bingen', 'binge', 'bingumer']
# Cluster 331: ['lychee', 'lychen', 'lychees']
# Cluster 332: ['jimmys', 'jimmy']
# Cluster 333: ['simitzade', 'simins', 'simianer', 'simit']
# Cluster 334: ['mile', 'mileta', 'miles']
# Cluster 335: ['mezedopolion', 'mesedopolio']
# Cluster 336: ['tbiliso', 'tbilissi']
# Cluster 337: ['lapointe', 'lapalma', 'lappa', 'lapp']
# Cluster 338: ['loosen', 'loose']
# Cluster 339: ['fasta', 'rapido']
# Cluster 340: ['tex', 'texmex']
# Cluster 341: ['melissa', 'kelly']
# Cluster 342: ['gardens', 'garden']
# Cluster 343: ['över', 'over']
# Cluster 344: ['feyen', 'feynsinn', 'fey']
# Cluster 345: ['fortschritt', 'förtsch']
# Cluster 346: ['shakes', 'shake', 'shaky']
# Cluster 347: ['caravanserei', 'caravan', 'caravano']
# Cluster 348: ['brunotte', 'brunos', 'bruno']
# Cluster 349: ['peaches', 'peach']
# Cluster 350: ['tigermilch', 'panthera', 'panther', 'tiger', 'lions', 'lion']
# Cluster 351: ['generatione', 'generation']
# Cluster 352: ['saveur', 'saverio', 'save']
# Cluster 353: ['flötzinger', 'flotzinger']
# Cluster 354: ['diablos', 'diablo']
# Cluster 355: ['milo', 'milow']
# Cluster 356: ['quacks', 'quack']
# Cluster 357: ['chad', 'chaddy', 'chada', 'chadias']
# Cluster 358: ['nobody', 'everybody']
# Cluster 359: ['jennys', 'jenny']
# Cluster 360: ['bone', 'bonema', 'bones']
# Cluster 361: ['lehmann', 'lehmanns']
# Cluster 362: ['joyway', 'joy', 'joynes']
# Cluster 363: ['live', 'living', 'life']
# Cluster 364: ['theresa', 'teresa']
# Cluster 365: ['jaipur', 'jaipuri']
# Cluster 366: ['satori', 'satoru', 'sato']
# Cluster 367: ['inningen', 'inninger']
# Cluster 368: ['outdoor', 'outside', 'in', 'inside', 'indoor']
# Cluster 369: ['volta', 'voltaire']
# Cluster 370: ['carpe', 'carpaccio']
# Cluster 371: ['partyservice', 'partylöwe', 'party', 'partykeller']
# Cluster 372: ['passione', 'passion', 'desiree']
# Cluster 373: ['maia', 'maiale', 'maiach']
# Cluster 374: ['wonnegauer', 'wonnegau']
# Cluster 375: ['svens', 'svenjas', 'sven']
# Cluster 376: ['south', 'southern']
# Cluster 377: ['cut', 'cuts', 'slices', 'slice']
# Cluster 378: ['donna', 'irene', 'peggys', 'irenes', 'donnas']
# Cluster 379: ['dresdener', 'dresden']
# Cluster 380: ['bums', 'bümmersteder', 'bum']
# Cluster 381: ['hooddog', 'hood']
# Cluster 382: ['bamboole', 'bamboo']
# Cluster 383: ['tödter', 'tödtenrieder', 'todtnauer']
# Cluster 384: ['como', 'comoda']
# Cluster 385: ['batho', 'bathasar']
# Cluster 386: ['dengel', 'deng']
# Cluster 387: ['gringos', 'gringo']
# Cluster 388: ['santiago', 'chileno', 'santiagos']
# Cluster 389: ['somma', 'komma']
# Cluster 390: ['punto', 'pünte', 'pünter']
# Cluster 391: ['gurume', 'guru']
# Cluster 392: ['champion', 'champor', 'champa', 'champ', 'champs', 'champions']
# Cluster 393: ['driver', 'driveri', 'drivers']
# Cluster 394: ['gaston', 'gastonomie']
# Cluster 395: ['aumatt', 'aumatal']
# Cluster 396: ['farmhouse', 'farmstead']
# Cluster 397: ['bardenhagen', 'bardele', 'bardolino', 'bard']
# Cluster 398: ['atmosphera', 'atmosfera']
# Cluster 399: ['bites', 'bite']
# Cluster 400: ['zimmermanns', 'zimmermann']
# Cluster 401: ['tölles', 'tolle', 'tollus', 'töller']
# Cluster 402: ['relaxzone', 'relax', 'relaxed']
# Cluster 403: ['indienking', 'indie', 'indieflavours', 'indien']
# Cluster 404: ['evas', 'evabd', 'eva', 'evapi']
# Cluster 405: ['manfred', 'manfreds']
# Cluster 406: ['babeuf', 'babes', 'babel']
# Cluster 407: ['francescana', 'francesca']
# Cluster 408: ['winandy', 'winand']
# Cluster 409: ['happen', 'happens']
# Cluster 410: ['matera', 'maternus', 'mater']
# Cluster 411: ['kick', 'kickelhahn']
# Cluster 412: ['troyka', 'troy']
# Cluster 413: ['arepa', 'arepas']
# Cluster 414: ['tidenhub', 'tide']
# Cluster 415: ['traditional', 'traditionale']
# Cluster 416: ['grain', 'grainer', 'grainerbräu']
# Cluster 417: ['squisita', 'squisito']
# Cluster 418: ['strikee', 'strike']
# Cluster 419: ['dalya', 'dalyan']
# Cluster 420: ['dinoris', 'dino', 'dinosaurier', 'dinos']
# Cluster 421: ['times', 'time', 'goodtime', 'mytime']
# Cluster 422: ['shot', 'bullet']
# Cluster 423: ['rouge', 'rougemarin']
# Cluster 424: ['agra', 'agrarhof', 'agrar']
# Cluster 425: ['faistenoy', 'faisal']
# Cluster 426: ['arbeitsgericht', 'arbeit']
# Cluster 427: ['gorenshi', 'goren']
# Cluster 428: ['smile', 'smiling', 'happy']
# Cluster 429: ['heroes', 'hero']
# Cluster 430: ['links', 'link']
# Cluster 431: ['legends', 'legend']
# Cluster 432: ['ntg', 'ntai', 'nt']
# Cluster 433: ['twist', 'twisters']
# Cluster 434: ['cherusker', 'cherng', 'cherry', 'cher']
# Cluster 435: ['archilleon', 'archimedes', 'arche', 'archeteri', 'archegono']
# Cluster 436: ['eleganz', 'wiegand', 'wiegands']
# Cluster 437: ['rheen', 'rhee']
# Cluster 438: ['costini', 'costiera']
# Cluster 439: ['borey', 'börek']
# Cluster 440: ['difference', 'compare', 'different']
# Cluster 441: ['element', 'elements', 'elemente']
# Cluster 442: ['sortino', 'sortie']
# Cluster 443: ['checker', 'checkinger']
# Cluster 444: ['becker', 'beckert', 'beckers', 'beckerwirt']
# Cluster 445: ['colina', 'collina', 'colin', 'colinar']
# Cluster 446: ['gatow', 'soltow']
# Cluster 447: ['helmuts', 'helmut']
# Cluster 448: ['willischza', 'willis']
# Cluster 449: ['potato', 'potatos']
# Cluster 450: ['seconds', 'minutes']
# Cluster 451: ['thoa', 'thoc']
# Cluster 452: ['gingerboy', 'ginger']
# Cluster 453: ['roya', 'royani', 'roy']
# Cluster 454: ['aspendos', 'aspen']
# Cluster 455: ['princess', 'prince']
# Cluster 456: ['tessiner', 'tesse']
# Cluster 457: ['corell', 'core']
# Cluster 458: ['orben', 'orbroich', 'orbach', 'orb']
# Cluster 459: ['axels', 'axel']
# Cluster 460: ['ippin', 'ip']
# Cluster 461: ['lucerna', 'luce', 'lucencia']
# Cluster 462: ['location', 'place']
# Cluster 463: ['pröve', 'show']
# Cluster 464: ['penn', 'penne']
# Cluster 465: ['lenau', 'lenas', 'lena']
# Cluster 466: ['kongfu', 'kong', 'kang', 'köngen']
# Cluster 467: ['anroll', 'handroll']
# Cluster 468: ['mono', 'monos']
# Cluster 469: ['bless', 'blesses']
# Cluster 470: ['athena', 'hercules', 'zeus']
# Cluster 471: ['dragseth', 'drago']
# Cluster 472: ['göttfried', 'gottfried']
# Cluster 473: ['beth', 'bethanien', 'bethof']
# Cluster 474: ['barres', 'barresto']
# Cluster 475: ['libanesische', 'libanesisches']
# Cluster 476: ['holly', 'tiffany', 'hollyfood']
# Cluster 477: ['shawarna', 'shawarma']
# Cluster 478: ['dimitri', 'dimitria']
# Cluster 479: ['sealords', 'sealand', 'sealounge']
# Cluster 480: ['ellis', 'ellissima']
# Cluster 481: ['what', 'whats']
# Cluster 482: ['experten', 'expert']
# Cluster 483: ['kickers', 'kickert', 'kickerstüble']
# Cluster 484: ['cometa', 'meteora']
# Cluster 485: ['homecooking', 'eventcooking']
# Cluster 486: ['internationales', 'internationale', 'overseas', 'international', 'foreign']
# Cluster 487: ['luisa', 'luisas']
# Cluster 488: ['greet', 'greetsiel']
# Cluster 489: ['heart', 'heartbeet']
# Cluster 490: ['gravemeier', 'gravenreuther', 'gravenbruch']
# Cluster 491: ['dynastie', 'dynasiey']
# Cluster 492: ['goot', 'goos']
# Cluster 493: ['oddugi', 'oddo']
# Cluster 494: ['appetito', 'appetize', 'appetit']
# Cluster 495: ['halong', 'halongbay']
# Cluster 496: ['muhammad', 'mohammad']
# Cluster 497: ['roastineer', 'roasters']
# Cluster 498: ['toast', 'toasty']
# Cluster 499: ['tisch', 'tisk']
# Cluster 500: ['knoblauchzehe', 'knobelbecher', 'knoblauch']
# Cluster 501: ['trierer', 'trier']
# Cluster 502: ['cargoitalia', 'trunk', 'cargo']
# Cluster 503: ['sansaro', 'sanssousi', 'sansushi', 'sanssouci', 'sans']
# Cluster 504: ['flemings', 'fleming']
# Cluster 505: ['blinden', 'blind']
# Cluster 506: ['mystica', 'magic', 'magica']
# Cluster 507: ['levi', 'levish']
# Cluster 508: ['crunchy', 'crunch']
# Cluster 509: ['gabriele', 'gabriel']
# Cluster 510: ['harput', 'harpstedt', 'harp']
# Cluster 511: ['brokeswalde', 'brokenlande']
# Cluster 512: ['düring', 'during']
# Cluster 513: ['grander', 'grande']
# Cluster 514: ['paradise', 'heaven']
# Cluster 515: ['uplengener', 'upjever', 'up', 'uppu', 'down', 'upe']
# Cluster 516: ['shamrock', 'patrick']
# Cluster 517: ['chico', 'chicos']
# Cluster 518: ['hefteralm', 'bäckeralm', 'stöckeralm']
# Cluster 519: ['robins', 'robinien', 'robin']
# Cluster 520: ['philosophenhöhe', 'philosophencaf', 'philosoph']
# Cluster 521: ['rentei', 'rentenversicherung', 'rentamt']
# Cluster 522: ['paradero', 'paradeismühle']
# Cluster 523: ['funs', 'fun']
# Cluster 524: ['pankoff', 'malakoff']
# Cluster 525: ['enzos', 'enzo']
# Cluster 526: ['abu', 'abuhakam']
# Cluster 527: ['pensione', 'pensions', 'pension']
# Cluster 528: ['jakova', 'vukova']
# Cluster 529: ['janeks', 'janemanns', 'janes']
# Cluster 530: ['solitude', 'solitudestüble']
# Cluster 531: ['signora', 'signore', 'signorina']
# Cluster 532: ['super', 'superb']
# Cluster 533: ['ostpark', 'rastpark']
# Cluster 534: ['quoc', 'quo']
# Cluster 535: ['janan', 'jana', 'janas']
# Cluster 536: ['judge', 'court']
# Cluster 537: ['extra', 'extrablatt']
# Cluster 538: ['feng', 'fenglers']
# Cluster 539: ['salvadors', 'salvador']
# Cluster 540: ['shark', 'sharky']
# Cluster 541: ['juicery', 'juice']
# Cluster 542: ['johnny', 'john', 'jonnys', 'johns', 'jonny']
# Cluster 543: ['no20', 'an20']
# Cluster 544: ['racing', 'speedway']
# Cluster 545: ['pyramids', 'pyramide']
# Cluster 546: ['wider', 'widerhold']
# Cluster 547: ['octupus', 'octogon']
# Cluster 548: ['dschungel', 'dschunke']
# Cluster 549: ['tendüre', 'tendur']
# Cluster 550: ['cognito', 'compagnie', 'compagniehaus']
# Cluster 551: ['bröker', 'brokers']
# Cluster 552: ['powers', 'power', 'powered']
# Cluster 553: ['elaine', 'olga', 'judy']
# Cluster 554: ['jessen', 'jessern', 'jesse']
# Cluster 555: ['charles', 'charlie']
# Cluster 556: ['cordes', 'cordobes', 'cord', 'cordon']
# Cluster 557: ['berching', 'berchumer', 'garching']
# Cluster 558: ['hoope', 'hoop']
# Cluster 559: ['highlight', 'highlights']
# Cluster 560: ['wavecity', 'wave']
# Cluster 561: ['bobos', 'boboq']
# Cluster 562: ['train', 'railroad', 'rail']
# Cluster 563: ['private', 'public']
# Cluster 564: ['jeff', 'geöffnet']
# Cluster 565: ['persian', 'persia']
# Cluster 566: ['doof', 'doon', 'doo']
# Cluster 567: ['crusty', 'crust']
# Cluster 568: ['neumann', 'neumanns', 'neumannmühle']
# Cluster 569: ['a', 'an']
# Cluster 570: ['alfred', 'alfreds']
# Cluster 571: ['diego', 'mateo']
# Cluster 572: ['warenbach', 'waren']
# Cluster 573: ['bananas', 'coconut', 'banana']
# Cluster 574: ['rack', 'rackl']
# Cluster 575: ['sigmaringen', 'sigma']
# Cluster 576: ['bf', 'bff', 'bffl']
# Cluster 577: ['ding', 'dingshang', 'dinger', 'dingle']
# Cluster 578: ['marketenderin', 'market']
# Cluster 579: ['cubi', 'cubo']
# Cluster 580: ['cordobar', 'cordoba']
# Cluster 581: ['quitzow', 'quitte']
# Cluster 582: ['sigiriya', 'nigiri']
# Cluster 583: ['andrea', 'lorenzo']
# Cluster 584: ['tunici', 'tunicis']
# Cluster 585: ['räther', 'rather']
# Cluster 586: ['job', 'jobusch', 'jobst', 'jöbstel']
# Cluster 587: ['verve5', 'verve']
# Cluster 588: ['holy', 'holymoly']
# Cluster 589: ['megas', 'mega', 'megasaray', 'megabite', 'megaron']
# Cluster 590: ['fock', 'föcker']
# Cluster 591: ['undosa', 'undorf']
# Cluster 592: ['wanted', 'want']
# Cluster 593: ['clay', 'benton']
# Cluster 594: ['table', 'tables']
# Cluster 595: ['ffc', 'ffm']
# Cluster 596: ['carmine', 'carmines']
# Cluster 597: ['lasso', 'lassi', 'lasser', 'lass']
# Cluster 598: ['santo', 'santorrini', 'santorin']
# Cluster 599: ['msc', 'bsc']
# Cluster 600: ['reusaer', 'reusenhus', 'reusenhaus', 'reuse']
# Cluster 601: ['missunde', 'miss']
# Cluster 602: ['buenavista', 'buena']
# Cluster 603: ['canal', 'canale']
# Cluster 604: ['saller', 'salle', 'sallento', 'sallenbusch', 'sallers']
# Cluster 605: ['roof', 'rooftop', 'roofensee']
# Cluster 606: ['oyler', 'ayler']
# Cluster 607: ['musetti', 'muselstüble', 'musette', 'muse']
# Cluster 608: ['devils', 'devil']
# Cluster 609: ['berenbostel', 'berens', 'berenbosteler']
# Cluster 610: ['tomek', 'jacek']
# Cluster 611: ['angelas', 'angela']
# Cluster 612: ['gunglstub', 'gunglstubn']
# Cluster 613: ['remo', 'ammolite', 'ammo']
# Cluster 614: ['kedioli', 'kedem', 'kedo']
# Cluster 615: ['locks', 'locky']
# Cluster 616: ['konstantin', 'konstantinos', 'ivan']
# Cluster 617: ['rice', 'ricebrothers']
# Cluster 618: ['arenaris', 'arenas', 'arena']
# Cluster 619: ['maudach', 'mauds']
# Cluster 620: ['canon', 'cannone', 'canone']
# Cluster 621: ['consilium', 'concilium']
# Cluster 622: ['bennyssimo', 'benny']
# Cluster 623: ['necmi', 'neco']
# Cluster 624: ['fewur', 'fewi']
# Cluster 625: ['accento', 'accent']
# Cluster 626: ['wörners', 'wörner']
# Cluster 627: ['savarin', 'savanne', 'savarona', 'savas']
# Cluster 628: ['montana', 'montanara', 'montanaro']
# Cluster 629: ['christy', 'becky']
# Cluster 630: ['paladion', 'paladino']
# Cluster 631: ['kruger', 'krüger', 'krügers']
# Cluster 632: ['moosenalm', 'mooser']
# Cluster 633: ['yin', 'ying']
# Cluster 634: ['hostellerie', 'hostel']
# Cluster 635: ['napoleonshöhe', 'bonaparte', 'napoleone', 'napoleon']
# Cluster 636: ['gerard', 'gerardy']
# Cluster 637: ['belly', 'tummy']
# Cluster 638: ['levels', 'level']
# Cluster 639: ['billstedt', 'dollart']
# Cluster 640: ['bingo', 'bingöl', 'bingooo']
# Cluster 641: ['chaophraya', 'chaopraya', 'chao']
# Cluster 642: ['tucano', 'chicano']
# Cluster 643: ['cindy', 'cindys']
# Cluster 644: ['emmendinger', 'emmen']
# Cluster 645: ['by', 'with']
# Cluster 646: ['rbir', 'rbina']
# Cluster 647: ['pinto', 'pintor']
# Cluster 648: ['wiggers', 'wigger']
# Cluster 649: ['siegel', 'siegelsbacher']
# Cluster 650: ['nulldreier', 'nullpunkt', 'null815', 'null']
# Cluster 651: ['alamut', 'alamanos', 'alamo']
# Cluster 652: ['willys', 'willy']
# Cluster 653: ['torchio', 'törchen']
# Cluster 654: ['dnipro', 'dzeladini']
# Cluster 655: ['w59', 'w66']
# Cluster 656: ['corner', 'corners']
# Cluster 657: ['smith', 'williams', 'morris']
# Cluster 658: ['brain', 'brainlab']
# Cluster 659: ['lights', 'light']
# Cluster 660: ['gradl', 'grad']
# Cluster 661: ['vulkana', 'vulkan', 'vulkanstube', 'vulkangrill']
# Cluster 662: ['menü', 'menuerestaurant']
# Cluster 663: ['nest', 'nesthenne', 'nestos', 'nesthocker']
# Cluster 664: ['vallendar', 'valle']
# Cluster 665: ['neo', 'neos']
# Cluster 666: ['dublin', 'dubliner', 'irish']
# Cluster 667: ['horizont', 'horizonte']
# Cluster 668: ['antiocheia', 'antiochia']
# Cluster 669: ['seepost', 'post']
# Cluster 670: ['moses', 'mosesmühle']
# Cluster 671: ['wisent', 'wisentreservat']
# Cluster 672: ['glashüttener', 'glashüttn', 'glashütten', 'glashütte', 'glashaus', 'glashofen']
# Cluster 673: ['check', 'checkin']
# Cluster 674: ['salsarico', 'salsa']
# Cluster 675: ['moody', 'mood', 'moods']
# Cluster 676: ['bellevue', 'bellevuechen']
# Cluster 677: ['varlemann', 'varlemanns']
# Cluster 678: ['ram', 'memory', 'memories']
# Cluster 679: ['classe', 'class']
# Cluster 680: ['viacity', 'via']
# Cluster 681: ['finale', 'final']
# Cluster 682: ['schumann', 'schumanns', 'schümanns']
# Cluster 683: ['icognito', 'inkognito', 'inka']
# Cluster 684: ['rexrodt', 'rexha', 'rexin', 'rexroth']
# Cluster 685: ['cooper', 'cooperativa']
# Cluster 686: ['concordia', 'concordiaturm']
# Cluster 687: ['numero', 'numnums']
# Cluster 688: ['bastards', 'bastard']
# Cluster 689: ['book', 'novel', 'novella']
# Cluster 690: ['some', 'lot', 'most', 'plenty', 'more', 'much']
# Cluster 691: ['leithner', 'leithenmühle']
# Cluster 692: ['kaplan', 'kaplanei']
# Cluster 693: ['rosenberg', 'rosenberger']
# Cluster 694: ['brow', 'browiede']
# Cluster 695: ['chen', 'chenab']
# Cluster 696: ['merendero', 'meren']
# Cluster 697: ['bonnies', 'bonnie']
# Cluster 698: ['angusto', 'angus']
# Cluster 699: ['rentner', 'rentschlers']
# Cluster 700: ['vitos', 'vito']
# Cluster 701: ['elephant', 'elephantenkeller']
# Cluster 702: ['elenas', 'elena']
# Cluster 703: ['reinsehlen', 'reinsche']
# Cluster 704: ['holsterhauser', 'holsterfeld']
# Cluster 705: ['blitzer', 'blitz']
# Cluster 706: ['tyde', 'tyo']
# Cluster 707: ['rösterei', 'rosteria']
# Cluster 708: ['rds', 'rda']
# Cluster 709: ['loki', 'lokikivi', 'lokitos']
# Cluster 710: ['landauer', 'landau']
# Cluster 711: ['chicks', 'chicking']
# Cluster 712: ['stammlokal', 'baumstammlokal']
# Cluster 713: ['sette', 'settele']
# Cluster 714: ['hoftheater', 'naturtheaters', 'amphitheater']
# Cluster 715: ['gustavs', 'gustav']
# Cluster 716: ['hommels', 'homme']
# Cluster 717: ['chungking', 'chung']
# Cluster 718: ['maze', 'labyrinth']
# Cluster 719: ['möve', 'mövenschiss']
# Cluster 720: ['select', 'selecta']
# Cluster 721: ['clara', 'clarapark']
# Cluster 722: ['coloniale', 'colonial']
# Cluster 723: ['authentica', 'authentic']
# Cluster 724: ['dente', 'denter']
# Cluster 725: ['woohoo', 'woog', 'woo']
# Cluster 726: ['deer', 'deern']
# Cluster 727: ['augusto', 'augustobar']
# Cluster 728: ['serve', 'servet']
# Cluster 729: ['quasi', 'quasimodo']
# Cluster 730: ['lukas', 'lukass']
# Cluster 731: ['monroes', 'monroe']
# Cluster 732: ['caldero', 'caldera']
# Cluster 733: ['brick', 'mortar', 'bricks']
# Cluster 734: ['christina', 'cristina']
# Cluster 735: ['anand', 'anandas', 'ananda']
# Cluster 736: ['drummer', 'drums']
# Cluster 737: ['barrios', 'barrio']
# Cluster 738: ['dyonysos', 'dyonisos']
# Cluster 739: ['marathon', 'run', 'running']
# Cluster 740: ['journal', 'journale']
# Cluster 741: ['seinerzeit', 'seine']
# Cluster 742: ['wyhra', 'wyndham']
# Cluster 743: ['marius', 'mariusz']
# Cluster 744: ['bender', 'benders']
# Cluster 745: ['thessalia', 'thessalonikni']
# Cluster 746: ['serenata', 'serena']
# Cluster 747: ['onocubes', 'ono']
# Cluster 748: ['altonaer', 'altona']
# Cluster 749: ['vitas', 'vita']
# Cluster 750: ['vezos', 'mezos']
# Cluster 751: ['stan', 'stanxxs']
# Cluster 752: ['wahlster', 'pelster']
# Cluster 753: ['codde', 'coda']
# Cluster 754: ['coup', 'promo']
# Cluster 755: ['porter', 'porterhouse']
# Cluster 756: ['bison', 'bisonstube']
# Cluster 757: ['usedom', 'usedomer']
# Cluster 758: ['confine', 'finefine']
# Cluster 759: ['thermen', 'thermopyle', 'therme', 'thermenwirt']
# Cluster 760: ['jr', 'junior']
# Cluster 761: ['comercial', 'comedia']
# Cluster 762: ['narasinga', 'nara']
# Cluster 763: ['höstenpumpe', 'hostert']
# Cluster 764: ['minerva', 'minervas']
# Cluster 765: ['service', 'services']
# Cluster 766: ['pic', 'image']
# Cluster 767: ['mayflower', '1620']
# Cluster 768: ['dantes', 'dante']
# Cluster 769: ['culture', 'cultural']
# Cluster 770: ['bottled', 'bottles', 'bottle']
# Cluster 771: ['studios', 'studio']
